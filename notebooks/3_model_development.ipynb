# %%
# 3_model_development.ipynb

# Model Development for KuaiRec Recommender System
# ================================================
#
# This notebook covers the third task of the project:
# 1. Implementing collaborative filtering models
# 2. Implementing content-based filtering models
# 3. Implementing sequence-aware models
# 4. Implementing hybrid approaches
# 5. Evaluating models on the training set

# Import necessary libraries
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import sparse
import pickle
from datetime import datetime
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# Add the src directory to the path so we can import our modules
sys.path.append(os.path.abspath("../"))
from src.models.collaborative import ALSModel
from src.models.content_based import ContentBasedModel
from src.models.sequence_aware import SequentialRules
from src.models.hybrid import LightGBMModel

# Set up directories
processed_dir = "../data/processed"
models_dir = "../models"
os.makedirs(models_dir, exist_ok=True)

# Load the data
print("Loading processed data...")
train_features = pd.read_csv(os.path.join(processed_dir, "train_features.csv"), low_memory=True)
user_features = pd.read_csv(os.path.join(processed_dir, "user_features.csv"), low_memory=True)
item_features = pd.read_csv(os.path.join(processed_dir, "item_features.csv"), low_memory=True)

# Load/create the interaction matrix
try:
    interaction_matrix = sparse.load_npz(os.path.join(processed_dir, "interaction_matrix.npz"))
    with open(os.path.join(processed_dir, "user_indices.pkl"), 'rb') as f:
        user_indices = pickle.load(f)
    with open(os.path.join(processed_dir, "item_indices.pkl"), 'rb') as f:
        item_indices = pickle.load(f)
    print("Loaded interaction matrix from file.")
except FileNotFoundError:
    print("Creating interaction matrix...")
    # Create user and item indices
    user_indices = {user: i for i, user in enumerate(train_features['user_id'].unique())}
    item_indices = {item: i for i, item in enumerate(train_features['video_id'].unique())}
    
    # Map user and item IDs to indices
    row_indices = train_features['user_id'].map(user_indices).values
    col_indices = train_features['video_id'].map(item_indices).values
    
    # Get rating values
    data = train_features['watch_ratio'].values
    
    # Build sparse matrix
    n_users = len(user_indices)
    n_items = len(item_indices)
    interaction_matrix = sparse.csr_matrix((data, (row_indices, col_indices)), shape=(n_users, n_items))
    
    # Save the matrix and indices
    sparse.save_npz(os.path.join(processed_dir, "interaction_matrix.npz"), interaction_matrix)
    with open(os.path.join(processed_dir, "user_indices.pkl"), 'wb') as f:
        pickle.dump(user_indices, f)
    with open(os.path.join(processed_dir, "item_indices.pkl"), 'wb') as f:
        pickle.dump(item_indices, f)

print(f"Data loaded. Train features shape: {train_features.shape}")
print(f"Interaction matrix shape: {interaction_matrix.shape}, density: {interaction_matrix.nnz / (interaction_matrix.shape[0] * interaction_matrix.shape[1]) * 100:.2f}%")

# 1. Collaborative Filtering Models
# --------------------------------

print("\n--- Training Collaborative Filtering Models ---")

print("\nTraining ALS model...")
als_model = ALSModel(factors=100)
als_model.fit(interaction_matrix)
als_model.save(os.path.join(models_dir, "als_model.pkl"))
print("ALS model trained and saved.")


# 2. Content-Based Filtering
# --------------------------

print("\n--- Training Content-Based Filtering Model ---")
content_model = ContentBasedModel()
content_model.fit(item_features, train_features)
content_model.save(os.path.join(models_dir, "content_model.pkl"))
print("Content-based model trained and saved.")

# 3. Sequence-Aware Model
# -----------------------

print("\n--- Training Sequence-Aware Model ---")
# Sort training data by user and timestamp to create sequences
if 'timestamp' in train_features.columns:
    train_features_sorted = train_features.sort_values(['user_id', 'timestamp'])
    
    seq_model = SequentialRules(max_sequence_length=5, min_support=2)
    seq_model.fit(train_features_sorted)
    seq_model.save(os.path.join(models_dir, "sequential_model.pkl"))
    print("Sequential model trained and saved.")
else:
    print("Timestamp column not found in training data. Skipping sequence-aware model.")

# 4. Hybrid Model
# --------------

print("\n--- Training Hybrid Model ---")
hybrid_model = LightGBMModel()
hybrid_model.fit(train_features)
hybrid_model.save(os.path.join(models_dir, "hybrid_model"))
print("Hybrid model trained and saved.")


# 5. Summary
# ---------

print("\n=== Model Development Summary ===")
print("1. Collaborative Filtering:")
print("   - Trained ALS model with 100 factors")

print("\n2. Content-Based Filtering:")
print("   - Trained model using video categories and engagement metrics")

print("\n3. Sequence-Aware Model:")
if 'seq_model' in locals():
    print("   - Trained sequential rules model with max sequence length of 5")
else:
    print("   - Not trained due to missing timestamp data")

print("\n4. Hybrid Model:")
print("   - Trained LightGBM model combining user, item, and interaction features")

print("\nAll models have been saved to the models directory.")
print("Next step: Implement the recommendation algorithm to generate recommendations for users.")
# Out:
# Loading processed data...
# Loaded interaction matrix from file.
# Data loaded. Train features shape: (3741835, 21)
# Interaction matrix shape: (1411, 3327), density: 79.71%
#
# --- Training Collaborative Filtering Models ---
#
# Training ALS model...
# ALS model trained and saved.
#
# --- Training Content-Based Filtering Model ---
# Content-based model trained and saved.
#
# --- Training Sequence-Aware Model ---
# Sequential model trained and saved.
#
# --- Training Hybrid Model ---
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.793290
# [LightGBM] [Info] Total Bins 1608
# [LightGBM] [Info] Number of data points in the train set: 2993468, number of used features: 14
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 2060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (34.26 MB) transferred to GPU in 0.062616 secs. 1 sparse feature groups
# [LightGBM] [Debug] Use subset for bagging
# [LightGBM] [Info] Start training from score 0.907228
# [LightGBM] [Debug] Re-bagging, using 2395705 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.42 MB) transferred to GPU in 0.051289 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 2394528 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.055089 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Re-bagging, using 2395001 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065497 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2395111 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065970 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Re-bagging, using 2394312 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.063913 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2395958 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.42 MB) transferred to GPU in 0.065270 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Re-bagging, using 2394915 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.063532 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2394909 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065704 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2393925 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.066388 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395237 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065805 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2394915 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065301 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2395352 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066473 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394977 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066216 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394666 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.067155 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2395432 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067615 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395608 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.42 MB) transferred to GPU in 0.064280 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2395642 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.42 MB) transferred to GPU in 0.066443 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2395979 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.42 MB) transferred to GPU in 0.067184 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394476 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.065248 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2395522 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066201 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Re-bagging, using 2394997 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065616 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394731 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066853 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394778 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065796 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Re-bagging, using 2394641 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.070903 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395389 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.070739 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 20
# [LightGBM] [Debug] Re-bagging, using 2395463 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.069489 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395060 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.068310 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Re-bagging, using 2396498 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.43 MB) transferred to GPU in 0.066055 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2396021 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.42 MB) transferred to GPU in 0.066517 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Re-bagging, using 2395067 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.070076 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394986 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065296 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2395110 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.069557 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395107 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.069810 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394404 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.068499 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2393754 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.39 MB) transferred to GPU in 0.067569 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395416 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067669 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394063 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.069846 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2394195 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.067613 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2394869 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066960 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2394373 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.067335 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Re-bagging, using 2393963 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.067501 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394673 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.056136 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2394961 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.054445 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2393666 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.39 MB) transferred to GPU in 0.053078 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2394452 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.058555 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Re-bagging, using 2395108 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.055285 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2393886 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.067681 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395036 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066127 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395055 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067938 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394321 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.066774 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395115 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067250 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2394323 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.066921 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Re-bagging, using 2394461 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.068638 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2394521 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.066849 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2394212 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.076624 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394666 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.075409 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2395204 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066004 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Re-bagging, using 2394989 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.071046 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395060 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065674 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394816 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067882 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2395087 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066615 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Re-bagging, using 2394236 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.066580 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395024 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067141 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395112 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067251 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2395185 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066701 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Re-bagging, using 2394486 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.066287 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2394855 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067648 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2393512 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.39 MB) transferred to GPU in 0.066436 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2394250 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.069398 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394915 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.072062 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2395180 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067055 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2394075 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.068597 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394796 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.079760 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2395380 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.068161 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2394734 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066159 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395137 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067615 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394423 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.068053 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394774 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.068218 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2395409 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.069542 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2395176 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067712 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Re-bagging, using 2394857 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065760 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395192 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067994 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2394447 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.067301 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394704 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.068036 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394901 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066264 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# ...
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066820 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2394240 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.067698 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2394131 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.069637 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2393680 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.39 MB) transferred to GPU in 0.068305 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2394896 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.077299 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Re-bagging, using 2394916 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066630 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395157 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067467 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394839 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067403 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Re-bagging, using 2395067 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066679 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395240 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.065894 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Re-bagging, using 2394670 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.069331 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2395173 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.066691 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2393363 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.39 MB) transferred to GPU in 0.067189 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394668 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.069668 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2395137 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.071658 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2395012 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.070046 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2394450 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.069699 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395238 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.068944 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Re-bagging, using 2393104 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.39 MB) transferred to GPU in 0.067149 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2396275 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.42 MB) transferred to GPU in 0.068307 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Re-bagging, using 2394643 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.068042 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Re-bagging, using 2394573 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.074262 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2394619 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.070145 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Re-bagging, using 2394913 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.068397 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Re-bagging, using 2393301 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.39 MB) transferred to GPU in 0.067960 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Re-bagging, using 2395140 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.067562 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 16
# [LightGBM] [Debug] Re-bagging, using 2395473 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.41 MB) transferred to GPU in 0.068625 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Re-bagging, using 2394296 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 12 dense feature groups (27.40 MB) transferred to GPU in 0.067847 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# Hybrid model trained and saved.
#
# === Model Development Summary ===
# 1. Collaborative Filtering:
#    - Trained ALS model with 100 factors
#
# 2. Content-Based Filtering:
#    - Trained model using video categories and engagement metrics
#
# 3. Sequence-Aware Model:
#    - Trained sequential rules model with max sequence length of 5
#
# 4. Hybrid Model:
#    - Trained LightGBM model combining user, item, and interaction features
#
# All models have been saved to the models directory.
# Next step: Implement the recommendation algorithm to generate recommendations for users.
